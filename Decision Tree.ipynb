# %%
import numpy as np 
import pandas as pd
import wget
from sklearn.tree import DecisionTreeClassifier
url = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/drug200.csv'
filename = wget.download(url)
my_data = pd.read_csv("drug200.csv", delimiter=",")
my_data[0:5]
# Out:
# 100% [................................................................................] 6027 / 6027
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
my_data.shape
# Out:
# (200, 6)

# %%
X = my_data[['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K']].values
X[0:5]
# Out:
# array([[23, 'F', 'HIGH', 'HIGH', 25.355],
#        [47, 'M', 'LOW', 'HIGH', 13.093],
#        [47, 'M', 'LOW', 'HIGH', 10.114],
#        [28, 'F', 'NORMAL', 'HIGH', 7.798],
#        [61, 'F', 'LOW', 'HIGH', 18.043]], dtype=object)

# %%
from sklearn import preprocessing
le_sex = preprocessing.LabelEncoder()
le_sex.fit(['F','M'])
X[:,1] = le_sex.transform(X[:,1]) 


le_BP = preprocessing.LabelEncoder()
le_BP.fit([ 'LOW', 'NORMAL', 'HIGH'])
X[:,2] = le_BP.transform(X[:,2])


le_Chol = preprocessing.LabelEncoder()
le_Chol.fit([ 'NORMAL', 'HIGH'])
X[:,3] = le_Chol.transform(X[:,3]) 

X[0:5]
# Out:
# array([[23, 0, 0, 0, 25.355],
#        [47, 1, 1, 0, 13.093],
#        [47, 1, 1, 0, 10.114],
#        [28, 0, 2, 0, 7.798],
#        [61, 0, 1, 0, 18.043]], dtype=object)

# %%
y = my_data["Drug"]
y[0:5]
# Out:
# 0    drugY
# 1    drugC
# 2    drugC
# 3    drugX
# 4    drugY
# Name: Drug, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
drugTree # it shows the default parameters
drugTree.fit(X_trainset,y_trainset)
predTree = drugTree.predict(X_testset)
print (predTree [0:5])
print (y_testset [0:5])
# Out:
# ['drugY' 'drugX' 'drugX' 'drugX' 'drugX']
# 40     drugY
# 51     drugX
# 139    drugX
# 197    drugX
# 170    drugX
# Name: Drug, dtype: object

# %%
# import metrics from sklearn and check the accuracy of our model.
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.9833333333333333

# %%
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\users\24729\miniconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.3.29  |       haa95532_1         122 KB  defaults
#     certifi-2021.10.8          |   py37haa95532_2         152 KB  defaults
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB  defaults
#     graphviz-2.38.0            |                4        37.7 MB  https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
#     openssl-1.1.1n             |       h2bbff1b_0         4.8 MB  defaults
#     python-graphviz-0.16       |     pyhd3eb1b0_1          20 KB  defaults
#     requests-2.27.1            |     pyhd3eb1b0_0          54 KB  defaults
#     ------------------------------------------------------------
#                                            Total:        42.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   graphviz           anaconda/pkgs/free/win-64::graphviz-2.38.0-4
#   python-graphviz    pkgs/main/noarch::python-graphviz-0.16-pyhd3eb1b0_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2021.7.5-haa95532_1 --> 2022.3.29-haa95532_1
#   certifi                          2021.5.30-py37haa95532_0 --> 2021.10.8-py37haa95532_2
#   openssl                                 1.1.1k-h2bbff1b_0 --> 1.1.1n-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# openssl-1.1.1n       | 4.8 MB    |            |   0%
# openssl-1.1.1n       | 4.8 MB    |            |   0%
# openssl-1.1.1n       | 4.8 MB    | 1          |   1%
# openssl-1.1.1n       | 4.8 MB    | 2          |   2%
# openssl-1.1.1n       | 4.8 MB    | 2          |   3%
# openssl-1.1.1n       | 4.8 MB    | 5          |   5%
# openssl-1.1.1n       | 4.8 MB    | 6          |   7%
# openssl-1.1.1n       | 4.8 MB    | 8          |   8%
# openssl-1.1.1n       | 4.8 MB    | 9          |   9%
# openssl-1.1.1n       | 4.8 MB    | #          |  11%
# openssl-1.1.1n       | 4.8 MB    | #2         |  13%
# openssl-1.1.1n       | 4.8 MB    | #3         |  14%
# openssl-1.1.1n       | 4.8 MB    | #4         |  14%
# openssl-1.1.1n       | 4.8 MB    | #4         |  15%
# openssl-1.1.1n       | 4.8 MB    | #4         |  15%
# openssl-1.1.1n       | 4.8 MB    | #6         |  16%
# openssl-1.1.1n       | 4.8 MB    | #7         |  17%
# openssl-1.1.1n       | 4.8 MB    | #9         |  20%
# openssl-1.1.1n       | 4.8 MB    | ##         |  20%
# openssl-1.1.1n       | 4.8 MB    | ##1        |  22%
# openssl-1.1.1n       | 4.8 MB    | ##2        |  22%
# openssl-1.1.1n       | 4.8 MB    | ##2        |  23%
# openssl-1.1.1n       | 4.8 MB    | ##3        |  24%
# openssl-1.1.1n       | 4.8 MB    | ##4        |  25%
# openssl-1.1.1n       | 4.8 MB    | ##4        |  25%
# openssl-1.1.1n       | 4.8 MB    | ##6        |  26%
# openssl-1.1.1n       | 4.8 MB    | ##7        |  27%
# openssl-1.1.1n       | 4.8 MB    | ##8        |  28%
# openssl-1.1.1n       | 4.8 MB    | ##9        |  30%
# openssl-1.1.1n       | 4.8 MB    | ###1       |  31%
# openssl-1.1.1n       | 4.8 MB    | ###1       |  32%
# openssl-1.1.1n       | 4.8 MB    | ###2       |  33%
# openssl-1.1.1n       | 4.8 MB    | ###3       |  34%
# openssl-1.1.1n       | 4.8 MB    | ###4       |  35%
# openssl-1.1.1n       | 4.8 MB    | ###5       |  36%
# openssl-1.1.1n       | 4.8 MB    | ###6       |  36%
# openssl-1.1.1n       | 4.8 MB    | ###7       |  37%
# openssl-1.1.1n       | 4.8 MB    | ###8       |  38%
# openssl-1.1.1n       | 4.8 MB    | ###9       |  39%
# openssl-1.1.1n       | 4.8 MB    | ###9       |  40%
# openssl-1.1.1n       | 4.8 MB    | ####       |  41%
# openssl-1.1.1n       | 4.8 MB    | ####1      |  41%
# openssl-1.1.1n       | 4.8 MB    | ####2      |  43%
# openssl-1.1.1n       | 4.8 MB    | ####3      |  43%
# openssl-1.1.1n       | 4.8 MB    | ####4      |  44%
# openssl-1.1.1n       | 4.8 MB    | ####4      |  45%
# openssl-1.1.1n       | 4.8 MB    | ####5      |  46%
# openssl-1.1.1n       | 4.8 MB    | ####6      |  47%
# openssl-1.1.1n       | 4.8 MB    | ####6      |  47%
# openssl-1.1.1n       | 4.8 MB    | ####7      |  47%
# openssl-1.1.1n       | 4.8 MB    | ####7      |  48%
# openssl-1.1.1n       | 4.8 MB    | ####8      |  48%
# openssl-1.1.1n       | 4.8 MB    | ####8      |  49%
# openssl-1.1.1n       | 4.8 MB    | ####9      |  50%
# openssl-1.1.1n       | 4.8 MB    | #####      |  50%
# openssl-1.1.1n       | 4.8 MB    | #####      |  51%
# openssl-1.1.1n       | 4.8 MB    | #####1     |  52%
# openssl-1.1.1n       | 4.8 MB    | #####2     |  52%
# openssl-1.1.1n       | 4.8 MB    | #####3     |  54%
# openssl-1.1.1n       | 4.8 MB    | #####4     |  54%
# openssl-1.1.1n       | 4.8 MB    | #####4     |  55%
# openssl-1.1.1n       | 4.8 MB    | #####5     |  55%
# openssl-1.1.1n       | 4.8 MB    | #####5     |  56%
# openssl-1.1.1n       | 4.8 MB    | #####5     |  56%
# openssl-1.1.1n       | 4.8 MB    | #####6     |  56%
# openssl-1.1.1n       | 4.8 MB    | #####6     |  57%
# openssl-1.1.1n       | 4.8 MB    | #####6     |  57%
# openssl-1.1.1n       | 4.8 MB    | #####7     |  57%
# openssl-1.1.1n       | 4.8 MB    | #####7     |  58%
# openssl-1.1.1n       | 4.8 MB    | #####8     |  59%
# openssl-1.1.1n       | 4.8 MB    | #####9     |  59%
# openssl-1.1.1n       | 4.8 MB    | #####9     |  60%
# openssl-1.1.1n       | 4.8 MB    | ######     |  60%
# openssl-1.1.1n       | 4.8 MB    | ######     |  60%
# openssl-1.1.1n       | 4.8 MB    | ######     |  61%
# openssl-1.1.1n       | 4.8 MB    | ######1    |  61%
# openssl-1.1.1n       | 4.8 MB    | ######1    |  62%
# openssl-1.1.1n       | 4.8 MB    | ######2    |  62%
# openssl-1.1.1n       | 4.8 MB    | ######2    |  63%
# openssl-1.1.1n       | 4.8 MB    | ######3    |  64%
# openssl-1.1.1n       | 4.8 MB    | ######3    |  64%
# openssl-1.1.1n       | 4.8 MB    | ######4    |  64%
# openssl-1.1.1n       | 4.8 MB    | ######4    |  65%
# openssl-1.1.1n       | 4.8 MB    | ######4    |  65%
# openssl-1.1.1n       | 4.8 MB    | ######5    |  66%
# openssl-1.1.1n       | 4.8 MB    | ######5    |  66%
# openssl-1.1.1n       | 4.8 MB    | ######6    |  67%
# openssl-1.1.1n       | 4.8 MB    | ######6    |  67%
# openssl-1.1.1n       | 4.8 MB    | ######7    |  68%
# openssl-1.1.1n       | 4.8 MB    | ######8    |  68%
# openssl-1.1.1n       | 4.8 MB    | ######8    |  69%
# openssl-1.1.1n       | 4.8 MB    | ######9    |  69%
# openssl-1.1.1n       | 4.8 MB    | ######9    |  70%
# openssl-1.1.1n       | 4.8 MB    | #######    |  71%
# openssl-1.1.1n       | 4.8 MB    | #######1   |  71%
# openssl-1.1.1n       | 4.8 MB    | #######1   |  72%
# openssl-1.1.1n       | 4.8 MB    | #######2   |  72%
# openssl-1.1.1n       | 4.8 MB    | #######2   |  72%
# openssl-1.1.1n       | 4.8 MB    | #######2   |  73%
# openssl-1.1.1n       | 4.8 MB    | #######3   |  73%
# openssl-1.1.1n       | 4.8 MB    | #######3   |  74%
# openssl-1.1.1n       | 4.8 MB    | #######3   |  74%
# openssl-1.1.1n       | 4.8 MB    | #######4   |  74%
# openssl-1.1.1n       | 4.8 MB    | #######4   |  75%
# openssl-1.1.1n       | 4.8 MB    | #######4   |  75%
# openssl-1.1.1n       | 4.8 MB    | #######5   |  76%
# openssl-1.1.1n       | 4.8 MB    | #######6   |  77%
# openssl-1.1.1n       | 4.8 MB    | #######7   |  77%
# openssl-1.1.1n       | 4.8 MB    | #######7   |  78%
# openssl-1.1.1n       | 4.8 MB    | #######8   |  78%
# openssl-1.1.1n       | 4.8 MB    | #######8   |  78%
# openssl-1.1.1n       | 4.8 MB    | #######9   |  79%
# openssl-1.1.1n       | 4.8 MB    | #######9   |  79%
# openssl-1.1.1n       | 4.8 MB    | ########   |  80%
# openssl-1.1.1n       | 4.8 MB    | ########   |  80%
# openssl-1.1.1n       | 4.8 MB    | ########   |  81%
# openssl-1.1.1n       | 4.8 MB    | ########1  |  81%
# openssl-1.1.1n       | 4.8 MB    | ########2  |  82%
# openssl-1.1.1n       | 4.8 MB    | ########2  |  83%
# openssl-1.1.1n       | 4.8 MB    | ########2  |  83%
# openssl-1.1.1n       | 4.8 MB    | ########3  |  83%
# openssl-1.1.1n       | 4.8 MB    | ########3  |  84%
# openssl-1.1.1n       | 4.8 MB    | ########3  |  84%
# openssl-1.1.1n       | 4.8 MB    | ########4  |  84%
# openssl-1.1.1n       | 4.8 MB    | ########4  |  85%
# openssl-1.1.1n       | 4.8 MB    | ########4  |  85%
# openssl-1.1.1n       | 4.8 MB    | ########5  |  85%
# openssl-1.1.1n       | 4.8 MB    | ########5  |  86%
# openssl-1.1.1n       | 4.8 MB    | ########6  |  86%
# openssl-1.1.1n       | 4.8 MB    | ########6  |  87%
# openssl-1.1.1n       | 4.8 MB    | ########6  |  87%
# openssl-1.1.1n       | 4.8 MB    | ########7  |  87%
# openssl-1.1.1n       | 4.8 MB    | ########7  |  88%
# openssl-1.1.1n       | 4.8 MB    | ########7  |  88%
# openssl-1.1.1n       | 4.8 MB    | ########8  |  88%
# openssl-1.1.1n       | 4.8 MB    | ########8  |  88%
# openssl-1.1.1n       | 4.8 MB    | ########9  |  89%
# openssl-1.1.1n       | 4.8 MB    | ########9  |  89%
# openssl-1.1.1n       | 4.8 MB    | ########9  |  90%
# openssl-1.1.1n       | 4.8 MB    | #########  |  90%
# openssl-1.1.1n       | 4.8 MB    | #########  |  90%
# openssl-1.1.1n       | 4.8 MB    | #########  |  91%
# openssl-1.1.1n       | 4.8 MB    | #########1 |  91%
# openssl-1.1.1n       | 4.8 MB    | #########1 |  92%
# openssl-1.1.1n       | 4.8 MB    | #########2 |  92%
# openssl-1.1.1n       | 4.8 MB    | #########2 |  92%
# openssl-1.1.1n       | 4.8 MB    | #########2 |  93%
# openssl-1.1.1n       | 4.8 MB    | #########3 |  93%
# openssl-1.1.1n       | 4.8 MB    | #########3 |  94%
# openssl-1.1.1n       | 4.8 MB    | #########3 |  94%
# openssl-1.1.1n       | 4.8 MB    | #########4 |  94%
# openssl-1.1.1n       | 4.8 MB    | #########4 |  95%
# openssl-1.1.1n       | 4.8 MB    | #########4 |  95%
# openssl-1.1.1n       | 4.8 MB    | #########5 |  95%
# openssl-1.1.1n       | 4.8 MB    | #########5 |  96%
# openssl-1.1.1n       | 4.8 MB    | #########6 |  96%
# openssl-1.1.1n       | 4.8 MB    | #########6 |  97%
# openssl-1.1.1n       | 4.8 MB    | #########6 |  97%
# openssl-1.1.1n       | 4.8 MB    | #########7 |  97%
# openssl-1.1.1n       | 4.8 MB    | #########7 |  98%
# openssl-1.1.1n       | 4.8 MB    | #########7 |  98%
# openssl-1.1.1n       | 4.8 MB    | #########8 |  98%
# openssl-1.1.1n       | 4.8 MB    | #########8 |  98%
# openssl-1.1.1n       | 4.8 MB    | #########8 |  99%
# openssl-1.1.1n       | 4.8 MB    | #########9 |  99%
# openssl-1.1.1n       | 4.8 MB    | #########9 |  99%
# openssl-1.1.1n       | 4.8 MB    | ########## | 100%
# openssl-1.1.1n       | 4.8 MB    | ########## | 100%
#
# charset-normalizer-2 | 35 KB     |            |   0%
# charset-normalizer-2 | 35 KB     | ####6      |  46%
# charset-normalizer-2 | 35 KB     | #########2 |  93%
# charset-normalizer-2 | 35 KB     | ########## | 100%
#
# graphviz-2.38.0      | 37.7 MB   |            |   0%
# graphviz-2.38.0      | 37.7 MB   |            |   0%
# graphviz-2.38.0      | 37.7 MB   |            |   0%
# graphviz-2.38.0      | 37.7 MB   |            |   0%
# graphviz-2.38.0      | 37.7 MB   | 1          |   1%
# graphviz-2.38.0      | 37.7 MB   | 2          |   2%
# graphviz-2.38.0      | 37.7 MB   | 3          |   3%
# graphviz-2.38.0      | 37.7 MB   | 4          |   5%
# graphviz-2.38.0      | 37.7 MB   | 5          |   6%
# graphviz-2.38.0      | 37.7 MB   | 6          |   7%
# graphviz-2.38.0      | 37.7 MB   | #          |  10%
# graphviz-2.38.0      | 37.7 MB   | #2         |  12%
# graphviz-2.38.0      | 37.7 MB   | #4         |  14%
# graphviz-2.38.0      | 37.7 MB   | #6         |  16%
# graphviz-2.38.0      | 37.7 MB   | #8         |  18%
# graphviz-2.38.0      | 37.7 MB   | #9         |  20%
# graphviz-2.38.0      | 37.7 MB   | ##         |  21%
# graphviz-2.38.0      | 37.7 MB   | ##2        |  22%
# graphviz-2.38.0      | 37.7 MB   | ##7        |  28%
# graphviz-2.38.0      | 37.7 MB   | ##9        |  29%
# graphviz-2.38.0      | 37.7 MB   | ###1       |  31%
# graphviz-2.38.0      | 37.7 MB   | ###5       |  36%
# graphviz-2.38.0      | 37.7 MB   | ###7       |  37%
# graphviz-2.38.0      | 37.7 MB   | ###9       |  39%
# graphviz-2.38.0      | 37.7 MB   | ####1      |  41%
# graphviz-2.38.0      | 37.7 MB   | ####2      |  42%
# graphviz-2.38.0      | 37.7 MB   | ####4      |  44%
# graphviz-2.38.0      | 37.7 MB   | ####5      |  46%
# graphviz-2.38.0      | 37.7 MB   | ####9      |  49%
# graphviz-2.38.0      | 37.7 MB   | #####4     |  54%
# graphviz-2.38.0      | 37.7 MB   | #####6     |  57%
# graphviz-2.38.0      | 37.7 MB   | #####8     |  59%
# graphviz-2.38.0      | 37.7 MB   | ######2    |  63%
# graphviz-2.38.0      | 37.7 MB   | ######5    |  65%
# graphviz-2.38.0      | 37.7 MB   | ######7    |  67%
# graphviz-2.38.0      | 37.7 MB   | ######8    |  69%
# graphviz-2.38.0      | 37.7 MB   | #######    |  71%
# graphviz-2.38.0      | 37.7 MB   | #######1   |  72%
# graphviz-2.38.0      | 37.7 MB   | #######3   |  74%
# graphviz-2.38.0      | 37.7 MB   | #######8   |  78%
# graphviz-2.38.0      | 37.7 MB   | ########   |  80%
# graphviz-2.38.0      | 37.7 MB   | ########2  |  82%
# graphviz-2.38.0      | 37.7 MB   | ########5  |  85%
# graphviz-2.38.0      | 37.7 MB   | ########7  |  87%
# graphviz-2.38.0      | 37.7 MB   | ########8  |  89%
# graphviz-2.38.0      | 37.7 MB   | #########  |  90%
# graphviz-2.38.0      | 37.7 MB   | #########4 |  95%
# graphviz-2.38.0      | 37.7 MB   | #########6 |  97%
# graphviz-2.38.0      | 37.7 MB   | #########8 |  99%
# graphviz-2.38.0      | 37.7 MB   | ########## | 100%
#
# certifi-2021.10.8    | 152 KB    |            |   0%
# certifi-2021.10.8    | 152 KB    | #          |  10%
# certifi-2021.10.8    | 152 KB    | ##         |  21%
# certifi-2021.10.8    | 152 KB    | ###1       |  31%
# certifi-2021.10.8    | 152 KB    | ####1      |  42%
# certifi-2021.10.8    | 152 KB    | #####2     |  52%
# certifi-2021.10.8    | 152 KB    | ######2    |  63%
# certifi-2021.10.8    | 152 KB    | #######3   |  73%
# certifi-2021.10.8    | 152 KB    | ########3  |  84%
# certifi-2021.10.8    | 152 KB    | #########4 |  94%
# certifi-2021.10.8    | 152 KB    | ########## | 100%
#
# requests-2.27.1      | 54 KB     |            |   0%
# requests-2.27.1      | 54 KB     | ##9        |  30%
# requests-2.27.1      | 54 KB     | #####9     |  60%
# requests-2.27.1      | 54 KB     | ########9  |  90%
# requests-2.27.1      | 54 KB     | ########## | 100%
#
# python-graphviz-0.16 | 20 KB     |            |   0%
# python-graphviz-0.16 | 20 KB     | #######8   |  78%
# python-graphviz-0.16 | 20 KB     | ########## | 100%
#
# ca-certificates-2022 | 122 KB    |            |   0%
# ca-certificates-2022 | 122 KB    | #3         |  13%
# ca-certificates-2022 | 122 KB    | ##6        |  26%
# ca-certificates-2022 | 122 KB    | ###9       |  39%
# ca-certificates-2022 | 122 KB    | #####2     |  52%
# ca-certificates-2022 | 122 KB    | ######5    |  66%
# ca-certificates-2022 | 122 KB    | #######8   |  79%
# ca-certificates-2022 | 122 KB    | #########1 |  92%
# ca-certificates-2022 | 122 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::conda==4.10.3=py37haa95532_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(144): Could not remove or rename C:\Users\24729\miniconda3\pkgs\setuptools-36.4.0-py36_1.tar.bz2.  Please remove this file manually (you may need to reboot to free file handles)
